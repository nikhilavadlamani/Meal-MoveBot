# %%
import pandas as pd
data = pd.read_csv('data.csv')
data
# Out:
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 5933                         Saffron Paneer Peda Recipe
# 5934  Italian Arancini Rice Balls Recipe With Delici...
# 5935        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 5936      Ullikadala Pulusu Recipe | Spring Onion Curry
# 5937  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  TotalTimeInMins  \
# 0     1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1      2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# ...

# %%
data[data['TotalTimeInMins']==0]
# Out:
#                                    TranslatedRecipeName  \
# 5149  Kakka Orotti Recipe - Steamed Mini Rice Balls ...
# 5620                             Besan vegetable recipe
#
#                                   TranslatedIngredients  TotalTimeInMins  \
# 5149  3 tablespoons Rice flour - adjustable,8 Curry ...                0
# 5620  1 teaspoon Turmeric powder (Haldi),1 teaspoon ...                0
#
#          Cuisine                             TranslatedInstructions  \
# 5149     Malabar  To begin making the Kakka Orotti recipe, we wi...
# 5620  Rajasthani  To begin making the Karela Besan Sabzi, first ...
#
#                                                     URL  \
# 5149  https://www.archanaskitchen.com/kakka-orotti-r...
# 5620  https://www.archanaskitchen.com/karela-besan-s...
#
#                                     Cleaned-Ingredients  \
# 5149  tomato,kashmiri red chilli powder,onion,chicke...
# 5620  salt,ginger,amchur (dry mango powder),karela (...
#
# ...

# %%
# replace the 2 zero time values 
data.at[5149,'TotalTimeInMins'] = 60
data.at[5620,'TotalTimeInMins'] = 40

# %%
new_data = data.to_csv('new_data.csv', index=False)

# %%
data1 = pd.read_csv('new_data.csv')
data1.isnull().sum()      # check for missing values
# Out:
# TranslatedRecipeName      0
# TranslatedIngredients     0
# TotalTimeInMins           0
# Cuisine                   0
# TranslatedInstructions    0
# URL                       0
# Cleaned-Ingredients       0
# image-url                 0
# Ingredient-count          0
# dtype: int64

# %%
data1[data1['TotalTimeInMins']==0]
# Out:
# Empty DataFrame
# Columns: [TranslatedRecipeName, TranslatedIngredients, TotalTimeInMins, Cuisine, TranslatedInstructions, URL, Cleaned-Ingredients, image-url, Ingredient-count]
# Index: []
